# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
sns.countplot(x="sex",data=df)

# %%
sns.countplot(x="sex",data=df,hue="pclass")

# %%
sns.countplot(x="survived",data=df,hue="sex")

# %%
df["age"].plot.hist()

# %%
df["fare"].plot.hist(bins=20,figsize=(10,5))

# %%
sns.countplot(x="sibsp",data=df)

# %%
g = sns.heatmap(df[["survived","sibsp","parch","age","fare"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
g = sns.FacetGrid(df, col='survived')
g = g.map(sns.distplot, "age")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #Veri Önisleme

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")

# %%
df.drop(["deck"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
sex=pd.get_dummies(df["sex"],drop_first=True)

# %%
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
df.embarked.value_counts()
# Out:
# S    554
# C    130
# Q     28
# Name: embarked, dtype: int64

# %%
embark=pd.get_dummies(df["embarked"],drop_first=True)

# %%
embark.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
pclass=pd.get_dummies(df["pclass"],drop_first=True)

# %%
pclass.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
df.drop(["sex","embarked","pclass"],inplace=True, axis=1)

# %%
df.head()
# Out:
#    survived   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0  22.0      1      0   7.2500  Third    man        True
# 1         1  38.0      1      0  71.2833  First  woman       False
# 2         1  26.0      0      0   7.9250  Third  woman       False
# 3         1  35.0      1      0  53.1000  First  woman       False
# 4         0  35.0      0      0   8.0500  Third    man        True
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True

# %%
df=pd.concat([df,sex,embark,pclass],axis=1)

# %%
df.head()
# Out:
#    survived   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0  22.0      1      0   7.2500  Third    man        True
# 1         1  38.0      1      0  71.2833  First  woman       False
# 2         1  26.0      0      0   7.9250  Third  woman       False
# 3         1  35.0      1      0  53.1000  First  woman       False
# 4         0  35.0      0      0   8.0500  Third    man        True
#
#    embark_town alive  alone  male  Q  S  2  3
# 0  Southampton    no  False     1  0  1  0  1
# 1    Cherbourg   yes  False     0  0  0  0  0
# 2  Southampton   yes   True     0  0  1  0  1
# 3  Southampton   yes  False     0  0  1  0  0
# 4  Southampton    no   True     1  0  1  0  1

# %%
df.dtypes
# Out:
# survived          int64
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# male              uint8
# Q                 uint8
# S                 uint8
# 2                 uint8
# 3                 uint8
# dtype: object

# %%
df.drop(["class","alive","embark_town","who","class","adult_male","alone"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived   age  sibsp  parch     fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500     1  0  1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0  0  0
# 2         1  26.0      0      0   7.9250     0  0  1  0  1
# 3         1  35.0      1      0  53.1000     0  0  1  0  0
# 4         0  35.0      0      0   8.0500     1  0  1  0  1

# %%
df.dtypes
# Out:
# survived      int64
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# male          uint8
# Q             uint8
# S             uint8
# 2             uint8
# 3             uint8
# dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X=df.drop("survived",axis=1)
y=df["survived"]

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.25,random_state=42)

# %%
logreg=LogisticRegression(max_iter=1000)

# %%
logreg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# LogisticRegression(max_iter=1000)

# %%
logreg.score(X_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# 0.7921348314606742

# %%
logreg.score(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# 0.8052434456928839

# %%
logreg=LogisticRegression(max_iter=1000,C=0.1)
logreg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# LogisticRegression(C=0.1, max_iter=1000)

# %%
print(logreg.score(X_test,y_test))
print(logreg.score(X_train,y_train))
# Out:
# 0.8033707865168539
# 0.8108614232209738
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
confusion_matrix(y_test,y_pred)
#https://medium.com/analytics-vidhya/what-is-a-confusion-matrix-d1c0f8feda5
# Out:
# array([[87, 12],
#        [23, 56]])

# %%
#b tahmin yapalim
df.head(1)
# Out:
#    survived   age  sibsp  parch  fare  male  Q  S  2  3
# 0         0  22.0      1      0  7.25     1  0  1  0  1

# %%
import numpy as np
new_df=np.array([[18,1,0,7.25,1,0,1,0,1]])

# %%
logreg.predict(new_df)
# Out:
# array([0])

# %%
logreg.coef_
# Out:
# array([[-0.02538523, -0.27496568,  0.02041592,  0.00974538, -1.65731823,
#         -0.1024372 , -0.2620807 , -0.17158722, -1.01632881]])

# %%
logreg.intercept_
# Out:
# array([1.90144697])

# %%
logreg.get_params()
# Out:
# {'C': 0.1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 1000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
# from sklearn.model_selection import GridSearchCV
# def tune_model(model,params):
#     modelCV=GridSearchCV(estimator=model,
#                      param_grid=params,
#                      scoring='accuracy',
#                      cv=5,
#                      n_jobs=-1,
#                      verbose=1)
#     modelCV.fit(X_train,y_train)
#     print("best parameters : \n{}\n".format(modelCV.best_params_))
#     print("accuracy : \n{}\n".format(modelCV.best_score_))

# %% [markdown]
# #Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='rbf',gamma=0.001,C=1000)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
#plot_results(y_test,pred,'Support Vector Classifier',plot_type='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[79, 20],
#        [23, 56]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79        99
#            1       0.74      0.71      0.72        79
#
#     accuracy                           0.76       178
#    macro avg       0.76      0.75      0.75       178
# weighted avg       0.76      0.76      0.76       178

# %%
import xgboost as xgb

# %%
boost=xgb.XGBClassifier(colsample_bytree=1,
                          eval_metric='error',
                          learning_rate=0.5,
                          min_child_weight=3,
                          nthread=-1,
                          gamma=0,
                          subsample=1,
                          max_depth=5,
)

# %%
boost.fit(X_train,y_train)
# Out:
# XGBClassifier(eval_metric='error', learning_rate=0.5, max_depth=5,
#               min_child_weight=3, nthread=-1)

# %%
y_pred=boost.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81        99
#            1       0.78      0.72      0.75        79
#
#     accuracy                           0.79       178
#    macro avg       0.79      0.78      0.78       178
# weighted avg       0.79      0.79      0.79       178

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
knn.fit(X_train,y_train)
Y_pred = knn.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
knn.score(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# 0.8426966292134831

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[83, 16],
#        [22, 57]])

# %%
# Random Forest

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, y_train)
confusion_matrix(y_test,y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# array([[83, 16],
#        [22, 57]])

# %%
print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        99
#            1       0.76      0.73      0.75        79
#
#     accuracy                           0.78       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.78      0.78      0.78       178

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, y_train)
y_pred = sgd.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[59 40]
#  [16 63]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        99
#            1       0.76      0.73      0.75        79
#
#     accuracy                           0.78       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.78      0.78      0.78       178
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
# Perceptron

perceptron = Perceptron()
perceptron.fit(X_train, y_train)
y_pred = perceptron.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[96  3]
#  [60 19]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        99
#            1       0.76      0.73      0.75        79
#
#     accuracy                           0.78       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.78      0.78      0.78       178
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
y_pred = gaussian.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,Y_pred))
# Out:
# [[78 21]
#  [21 58]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        99
#            1       0.76      0.73      0.75        79
#
#     accuracy                           0.78       178
#    macro avg       0.78      0.78      0.78       178
# weighted avg       0.78      0.78      0.78       178
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
